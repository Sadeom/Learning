# %% [markdown]
# <a href="https://colab.research.google.com/github/Sadeom/Learning/blob/master/Introdu%C3%A7%C3%A3o_a_collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade1 = 39
idade2 = 30
idade3 = 27
idade4 = 18

print(idade1)
print(idade2)
print(idade3)
print(idade4)
# Out:
# 39
# 30
# 27
# 18

# %%
idades = [39, 30, 27, 18]
type(idades)
# Out:
# list

# %%
len(idades)
# Out:
# 4

# %%
idades[0]
# Out:
# 39

# %%
idades
# Out:
# [39, 30, 27, 18]

# %%
print (idades[1])
print(idades[2])
print(idades[3])
print(idades[0])
# Out:
# 30
# 27
# 18
# 39

# %%
idades = 29
idades.append(28)
idades.append(27)
idades.appende(26)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-5af483809917> in <module>()
#       1 idades = 29
# ----> 2 idades.append(28)
#       3 idades.append(27)
#       4 idades.appende(26)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
 idades = [39]

# %%
idades
# Out:
# [39]

# %%
idades.append(38)

# %%
idades.insert(0, 40)

# %%
idades
# Out:
# [40, 39, 38]

# %%
if 40 in idades:
  idades.remove(40)
  print(idades)
# Out:
# [39, 38]

# %%
if 40 in idades:
  print(idades)
else:
  idades.append(40)
  print(idades)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5adeff7439b5> in <module>()
# ----> 1 if 40 in idades:
#       2   print(idades)
#       3 else:
#       4   idades.append(40)
#       5   print(idades)
#
# NameError: name 'idades' is not defined

# %%
idades = [20, 39, 18]
idades.append([27,19])
idades
for elemento in idades:
  print("Recebi o elemento", elemento)
# Out:
# Recebi o elemento 20
# Recebi o elemento 39
# Recebi o elemento 18
# Recebi o elemento [27, 19]

# %%
idades = [20, 39, 18]
idades.extend([27, 19])
idades
# Out:
# [20, 39, 18, 27, 19]

# %%
for idade in idades:
  print(idade + 1)
# Out:
# 21
# 40
# 19
# 28
# 20

# %%
idades_no_ano_que_vem = []
for idade in idades:
  idades_no_ano_que_vem.append(idade + 1)
  idades_no_ano_que_vem

# %%
idades_no_ano_que_vem
# Out:
# [21, 40, 19, 28, 20]

# %%
idade1 = 39
idade2 = 30
idade3 = 27
idade4 = 18

print(idade1)
print(idade2)
print(idade3)
print(idade4)

list[39, 30, 27, 18]

list
# Out:
# 39
# 30
# 27
# 18
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-0c7afca50ecf> in <module>()
#       9 print(idade4)
#      10
# ---> 11 list[39, 30, 27, 18]
#      12
#      13 list
#
# TypeError: 'type' object is not subscriptable

# %%
idades = [39,30,27,18]

# %%
type(idades)
# Out:
# list

# %%
len(idades)
# Out:
# 4

# %%
idades [                                                                                                                                                                                                                                                                  ]
# Out:
#   File "<ipython-input-9-79ec8d55ca98>", line 1
#     idades [                                                                                                                                                                                                                                                                  ]
#                                                                                                                                                                                                                                                                               ^
# SyntaxError: invalid syntax

# %%
idades[01]
# Out:
#   File "<ipython-input-10-f82492649a0b>", line 1
#     idades[01]
#             ^
# SyntaxError: invalid token

# %%
idades[0]
# Out:
# 39

# %%
print(idades[1])
print(idades[2])
print(idades[3])
# Out:
# 30
# 27
# 18

# %%
idades.append(15)

# %%
idades
# Out:
# [39, 30, 27, 18, 15]

# %%
idades[4]
# Out:
# 15

# %%
idades[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-9afc071113c0> in <module>()
# ----> 1 idades[5]
#
# IndexError: list index out of range

# %%
for idade in idades:
  print(idade)
# Out:
# 39
# 30
# 27
# 18
# 15

# %%
idades.remove(30)

# %%
idades
# Out:
# [39, 27, 18, 15]

# %%
idades.append(15)

# %%
idades
# Out:
# [39, 27, 18, 15, 15]

# %%
idades.remove(15)

# %%
idades
# Out:
# [39, 27, 18, 15]

# %%
idades.append(27)
idades.remove(27)
idades
# Out:
# [39, 18, 15, 27]

# %%
28 in idades
# Out:
# False

# %%
27 in idades
# Out:
# True

# %%
if 15 in idades:
  idades.remove(15)
  print(idades)
# Out:
# [39, 18, 27]

# %%
idades.insert(0, 20)

# %%
idades
# Out:
# [20, 39, 18, 27]

# %%
idades.append([27, 29])

# %%
idades
# Out:
# [20, 39, 18, 27, [27, 29]]

# %%
for elemento in idades:
  print("Recebi o elemento", elemento)
# Out:
# Recebi o elemento 20
# Recebi o elemento 39
# Recebi o elemento 18
# Recebi o elemento 27
# Recebi o elemento [27, 29]

# %%
idades = [20, 39, 18]

# %%
idades.extend([27, 19])
idades
# Out:
# [20, 39, 18, 27, 19]

# %%
for idade in idades:
  print(idade + 1)
# Out:
# 21
# 40
# 19
# 28
# 20

# %%
idades_no_ano_que_vem = {}
for idade in idades:
  idades_no_ano_que_vem.append(idade+1)
  idades_no_ano_que_vem
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-36ed7cbc0fae> in <module>()
#       1 idades_no_ano_que_vem = {}
#       2 for idade in idades:
# ----> 3   idades_no_ano_que_vem.append(idade+1)
#       4   idades_no_ano_que_vem
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
idades_no_ano_que_vem = {}

# %%
for idade in idades:
  idades_no_ano_que_vem.append(idade+1)
  idades_no_ano_que_vem
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-d4ae1fedd1cc> in <module>()
#       1 for idade in idades:
# ----> 2   idades_no_ano_que_vem.append(idade+1)
#       3   idades_no_ano_que_vem
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
idades_no_ano_que_vem = []
for idade in idades:
  idades_no_ano_que_vem.append(idade+1)
  idades_no_ano_que_vem

# %%
idades_no_ano_que_vem
# Out:
# [21, 40, 19, 28, 20]

# %%
idades_no_ano_que_vem = [(idade+1) for idade in idades]
idades_no_ano_que_vem
# Out:
# [21, 40, 19, 28, 20]

# %%
[(idade) for idade in idades if idade > 21]
# Out:
# [39, 27]

# %%
idade
# Out:
# 19

# %%
idades
# Out:
# [20, 39, 18, 27, 19]

# %%
def proximo_ano(idade):
  return idade+1

[proximo_ano(idade) for idade in idades if idade > 21]
# Out:
# [40, 28]

# %%
def faz_processamento_de_visualizacao(lista):
  print(len(lista))
  list.append(13)
# Out:
# [16, 21, 29, 56, 43]

# %%
idades = [16, 21, 29, 56, 43]
faz_processamento_de_visualizacao(idades)
idades
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-dc6c07cb8926> in <module>()
#       1 idades = [16, 21, 29, 56, 43]
# ----> 2 faz_processamento_de_visualizacao(idades)
#       3 idades
#
# <ipython-input-59-dbad0ec543ee> in faz_processamento_de_visualizacao(lista)
#       1 def faz_processamento_de_visualizacao(lista):
#       2   print(len(lista))
# ----> 3   list.append(13)
#       4 idades
#
# TypeError: descriptor 'append' requires a 'list' object but received a 'int'

# %%
def faz_processamento_de_visualizacao(lista):
  print(len(lista))
  lista.append(13)

# %%
idades = [16, 21, 29, 56, 43]
faz_processamento_de_visualizacao(idades)
idades
# Out:
# 5
# [16, 21, 29, 56, 43, 13]

# %%
def faz_processamento_de_visualizacao(lista = list()):
  print(len(lista))
  print(lista)
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
# Out:
# 0
# []

# %%
faz_processamento_de_visualizacao()
# Out:
# 1
# [13]

# %%
faz_processamento_de_visualizacao()
# Out:
# 2
# [13, 13]

# %%
faz_processamento_de_visualizacao()
# Out:
# 3
# [13, 13, 13]

# %%
faz_processamento_de_visualizacao
# Out:
# <function __main__.faz_processamento_de_visualizacao>

# %%
def faz_processamento_de_visualizacao(lista = None):
  if lista == None:
    lista = list()
  print(len(lista))
  print(lista)
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
# Out:
# 0
# []
# 0
# []
# 0
# []
# 0
# []

# %% [markdown]
# Objetos Próprios

# %%
class ContaCorrente:
  def __init__(self, codigo):
    self.codigo = codigo
    self.saldo = 0

  def deposita(self, valor):
    self.saldo += valor

  def __str__(self):
    return "[>>Codigo {} Saldo {}<<]".format(self.codigo, self.saldo)

# %%
conta_do_gui = ContaCorrente(15)
print(conta_do_gui)
# Out:
# [>>Codigo 15 Saldo 0<<]

# %%
conta_do_gui.deposita(500)
print(conta_do_gui)
# Out:
# [>>Codigo 15 Saldo 500<<]

# %%
conta_da_dani = ContaCorrente(47685)
conta_da_dani.deposita(1000)
print(conta_da_dani)
# Out:
# [>>Codigo 47685 Saldo 1000<<]

# %%
contas = [conta_do_gui, conta_da_dani]
for conta in contas:
  print(conta)
# Out:
# [>>Codigo 15 Saldo 500<<]
# [>>Codigo 47685 Saldo 1000<<]

# %%
contas = [conta_do_gui, conta_da_dani, conta_do_gui]

# %%
print(contas[0])
# Out:
# [>>Codigo 15 Saldo 500<<]

# %%
conta_do_gui.deposita(100)

# %%
conta_do_gui

# %%
contas
# Out:
# [<__main__.ContaCorrente at 0x7f3d084c3490>,
#  <__main__.ContaCorrente at 0x7f3d084dac50>,
#  <__main__.ContaCorrente at 0x7f3d084c3490>]

# %%
print(contas[0])
# Out:
# [>>Codigo 15 Saldo 600<<]

# %%
contas = [conta_do_gui, conta_da_dani]

# %%
print(contas[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-1cb4a673b345> in <module>()
# ----> 1 print(contas[2])
#
# IndexError: list index out of range

# %%
contas[2].deposita(300)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-e325c2d0ca71> in <module>()
# ----> 1 contas[2].deposita(300)
#
# IndexError: list index out of range

# %%
conta_do_gui

# %%
print(conta_do_gui)
# Out:
# [>>Codigo 15 Saldo 600<<]

# %%
def deposita_para_todas(contas):
  for conta in contas:
    conta.deposita(100)

contas = [conta_do_gui, conta_da_dani]
print(contas[0], contas[1])
deposita_para_todas(contas)
print(contas[0], contas[1])
# Out:
# [>>Codigo 15 Saldo 600<<] [>>Codigo 47685 Saldo 1000<<]
# [>>Codigo 15 Saldo 700<<] [>>Codigo 47685 Saldo 1100<<]

# %%
contas.insert(0, 76)
print(contas[0], contas[1], contas[2])
# Out:
# 76 [>>Codigo 15 Saldo 700<<] [>>Codigo 47685 Saldo 1100<<]

# %%
deposita_para_todas(contas)
print(contas[0], contas[1], contas[2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-92ac4487eece> in <module>()
# ----> 1 deposita_para_todas(contas)
#       2 print(contas[0], contas[1], contas[2])
#
# <ipython-input-94-5c36215b3621> in deposita_para_todas(contas)
#       1 def deposita_para_todas(contas):
#       2   for conta in contas:
# ----> 3     conta.deposita(100)
#       4
#       5 contas = [conta_do_gui, conta_da_dani]
#
# AttributeError: 'int' object has no attribute 'deposita'

# %%
guilherme = ('Guilherme', 37, 1981) # tupla
daniela = ('Daniela', 31, 1987) 
# paulo = (39, 'Paulo, 1979) # ruim

# %%
guilherme.append(1234)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-c4e4d7e68ab2> in <module>()
# ----> 1 guilherme.append(1234)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
conta_do_gui = (15, 1000)
conta_do_gui.deposita() # variação oo

conta_do_gui[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-470796527b8f> in <module>()
#       1 conta_do_gui = (15, 1000)
# ----> 2 conta_do_gui.deposita() # variação oo
#       3
#       4 conta_do_gui[1]
#
# AttributeError: 'tuple' object has no attribute 'deposita'

# %%
def deposita(conta): # variação "funcional"(separando o comporto dos dados)
  novo_saldo = conta[1] + 100
  codigo = conta[0]
  return (codigo, novo_saldo)

# %%
deposita(conta_do_gui)
# Out:
# (15, 1100)

# %%
conta_do_gui
# Out:
# (15, 1000)

# %%
conta_do_gui = deposita(conta_do_gui)

# %%
conta_do_gui
# Out:
# (15, 1100)

# %%
usuarios = [guilherme, daniela]
usuarios
# Out:
# [('Guilherme', 37, 1981), ('Daniela', 31, 1987)]

# %%
usuarios.append(('Paulo', 39, 1979))

# %%
usuarios
# Out:
# [('Guilherme', 37, 1981), ('Daniela', 31, 1987), ('Paulo', 39, 1979)]

# %%
usuarios[0][0] = 'Guilherme Silveira'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-dc00118821b7> in <module>()
# ----> 1 usuarios[0][0] = 'Guilherme Silveira'
#
# TypeError: 'tuple' object does not support item assignment

# %%
conta_do_gui = ContaCorrente(15)
conta_do_gui.deposita(500)
conta_da_dani = ContaCorrente(234876)
conta_da_dani.deposita(1000)

contas = (conta_do_gui, conta_da_dani)

# %%
for conta in contas:
  print(conta)
# Out:
# [>>Codigo 15 Saldo 500<<]
# [>>Codigo 234876 Saldo 1000<<]

# %%
contas.append(322222)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-4ad0c355054b> in <module>()
# ----> 1 contas.append(322222)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
contas[0].deposita(300)

# %%
for conta in contas:
  print(conta)
# Out:
# [>>Codigo 15 Saldo 800<<]
# [>>Codigo 234876 Saldo 1000<<]

# %% [markdown]
# # **Herança e polimorfismo negrito**

# %%
from abc import ABCMeta, abstractmethod

class Conta(metaclass=ABCMeta):
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def deposita(self, valor):
    self._saldo += valor
  
  @abstractmethod
  def passa_o_mes(self):
    pass

  def __str__(self):
    return "[>>Codigo {} Saldo {}<<]".format(self._codigo, self._saldo)

# %%
print(Conta(88))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-bcabbe50454b> in <module>()
# ----> 1 print(Conta(88))
#
# TypeError: Can't instantiate abstract class Conta with abstract methods passa_o_mes

# %%
class ContaCorrente(Conta):

  def passa_o_mes(self):
    self._saldo -=2

class ContaPoupanca(Conta):

  def passa_o_mes(self):
    self._saldo *= 1.01
    self._saldo -= 3

class ContaInvestimento(Conta):
  pass

# %%
ContaInvestimento(764)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-88113fa11745> in <module>()
# ----> 1 ContaInvestimento(764)
#
# TypeError: Can't instantiate abstract class ContaInvestimento with abstract methods passa_o_mes

# %%
conta16 = ContaCorrente(16)
conta16.deposita(1000)
conta16.passa_o_mes()
print(conta16)
# Out:
# [>>Codigo 16 Saldo 998<<]

# %%
conta17 = ContaPoupanca(17)
conta17.deposita(1000)
conta17.passa_o_mes()
print(conta17)
# Out:
# [>>Codigo 17 Saldo 1007.0<<]

# %%
conta16 = ContaCorrente(16)
conta16.deposita(1000)
conta17 = ContaPoupanca(17)
conta17.deposita(1000)
contas = (conta16, conta17)

for conta in contas:
  conta.passa_o_mes() #duck typing
  print(conta)
# Out:
# [>>Codigo 16 Saldo 998<<]
# [>>Codigo 17 Saldo 1007.0<<]

# %% [markdown]
# # **evitaremos usar array puro, se precisarmos de trabalho numérico é costume usar o numpy**

# %%
import array as arr

arr.array('d', [1, 3.5])
# Out:
# array('d', [1.0, 3.5])

# %%
arr.array('d', [1, 3.5, 'Guilherme'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b1a4380a9c4e> in <module>()
# ----> 1 arr.array('d', [1, 3.5, 'Guilherme'])
#
# TypeError: must be real number, not str

# %%
# !pip install numpy

# %%
import numpy as np

numeros = np.array([1, 3.5])
numeros

# %%
numeros + 3

# %%
class ContaSalario:
  def __init__(self, codigo): 
    self._codigo = codigo
    self._saldo = 0

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>>Codigo {} Saldo {}<<]".format(self._codigo, self._saldo)

# %%
conta1 = ContaSalario(37)
print(conta1)

# %%
conta2 = ContaSalario(37)
print(conta2)

# %%
conta1 == conta2

# %%
contas = [conta1]
conta1 in contas

# %%
conta2 in contas

# %%
class ContaSalario:
  def __init__(self, codigo): 
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    return self._codigo == outro._codigo  

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>>Codigo {} Saldo {}<<]".format(self._codigo, self._saldo)

# %%
conta1 = ContaSalario(37)
conta2 = ContaSalario(37)
conta1 == conta2

# %%
conta1 != conta2

# %%
conta1 in [conta2]

# %%
class ContaSalario:
  def __init__(self, codigo): 
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    return self._codigo == outro._codigo and self._saldo == outro._saldo  

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>>Codigo {} Saldo {}<<]".format(self._codigo, self._saldo)

# %%
conta1 = ContaSalario(37)
conta2 = ContaSalario(37)
conta1 == conta2

# %%
conta1.deposita(10)

# %%
conta1 == conta2

# %%
class ContaSalario:
  def __init__(self, codigo): 
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False

    return self._codigo == outro._codigo and self._saldo == outro._saldo  

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>>Codigo {} Saldo {}<<]".format(self._codigo, self._saldo)

# %%
conta1 = ContaSalario(37)
conta2 = ContaCorrente(37)

# %%
conta1 == conta2

# %%
isinstance(ContaCorrente(34), ContaCorrente)

# %%
isinstance(ContaCorrente(34), Conta)

# %%
class ContaSalario:
  def __init__(self, codigo): 
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False

    return self._codigo == outro._codigo and self._saldo == outro._saldo  

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>>Codigo {} Saldo {}<<]".format(self._codigo, self._saldo)

class ContaMultiploSalario(ContaSalario):
  pass

# %%
idades = [15, 87, 32, 65, 56, 32, 49, 37]

for i in range(len(idades)):
  print(i, idades[1])
# Out:
# 0 87
# 1 87
# 2 87
# 3 87
# 4 87
# 5 87
# 6 87
# 7 87
